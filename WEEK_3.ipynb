# %%
from textblob import TextBlob

# %%
sample = TextBlob("appple")
result = sample.correct()
result
# Out:
# TextBlob("apple")

# %%
ls = ["languagee", "appplee"]
s2 = TextBlob("languagee appplee")
s2.correct()
# Out:
# TextBlob("language apple")
